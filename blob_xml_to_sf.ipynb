# %%
# python 3.11
# pip install azure-storage-blob
# pip install snowflake-snowpar0k-python

# %%
from snowflake.snowpark import Session
import os
import xml.etree.ElementTree as ET
import sys
import datetime
from azure.storage.blob import BlobServiceClient
import re

connection_parameters = {
   "account": "kd66798.ca-central-1.aws",
   "user": "PRAVEEN11001",
   "password": "XXXXXXXXXXXXX",
   "role": "ACCOUNTADMIN",  # optional
   "warehouse": "COMPUTE_WH",  # optional
   "database": "DEMO",  # optional
   "schema": "PUBLIC"  # optional
}

session = Session.builder.configs(connection_parameters).create()

# %%
# Azure Blob Storage configuration
container_name = "gold"
blob_folder_name = "xmls"
chunked_folder_name = "chunked_xmls"
file_type = "xml"
storage_account_name = "myadlsatic"
sas_token = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
storage_account_key = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX=="
connection_string = f"DefaultEndpointsProtocol=https;AccountName={storage_account_name};AccountKey={storage_account_key};EndpointSuffix=core.windows.net"
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)

# %%
def put_xml(xmlstring):
    
    tree = ET.ElementTree(ET.fromstring(xmlstring))
    root = tree.getroot()

    for _, child in enumerate(root.findall("./*")):
        child_str = ET.tostring(child, encoding='utf-8').decode('utf-8')
        xml_size = sys.getsizeof(child_str)

        if xml_size > 16000000:
            print(f"working for child {child.tag}")
            child_size = len(child)
            number_of_chunks = xml_size // 16000000 + 1
            grand_children_per_child = child_size // number_of_chunks
            remainder = child_size % number_of_chunks
            start_idx = 0

            for i in range(number_of_chunks):
                new_root = ET.Element(child.tag)
                end_idx = start_idx + grand_children_per_child + (1 if i < remainder else 0)

                for selected_children in child[start_idx:end_idx]:
                    new_root.append(selected_children)

                grand_root = ET.Element(root.tag)
                grand_root.append(new_root)
                new_tree = ET.ElementTree(grand_root)
                new_root = new_tree.getroot()
                xml_string = ET.tostring(new_root, encoding='utf-8')
                blob_name = f"{chunked_folder_name}/{child.tag}_{i}.xml"
                print(f"putting {child.tag}_{i} at {blob_name}")
                blob_client = container_client.get_blob_client(blob=blob_name)
                blob_client.upload_blob(xml_string, overwrite=True)

        else:
            print(f"working for child {child.tag}")
            new_root = ET.Element(root.tag)
            new_root.append(child)
            new_tree = ET.ElementTree(new_root)
            new_root = new_tree.getroot()
            xml_string = ET.tostring(new_root, encoding='utf-8')
            blob_name = f"{chunked_folder_name}/{child.tag}.xml"
            print(f"putting {child.tag} at {blob_name}")
            blob_client = container_client.get_blob_client(blob=blob_name)
            blob_client.upload_blob(xml_string, overwrite=True)

# %%
def copy_into_sf(session, folder_name,  filename):

    copy_date = datetime.datetime.utcnow()

    copy_result = (session.sql(f"""
    copy into xml_table(filename, xml_data, copy_date)
    from (select '{filename}' as filename, $1 as xml_data, '{copy_date}' as copy_date from @azure_stage/{folder_name}/{filename}.xml)
    on_error='skip_file'
    file_format= (format_name=my_xml_ff);
    """).collect())

    print(copy_result)

# %%
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
yesterday_date = datetime.datetime.utcnow().date() - datetime.timedelta(days=1)
container_client = blob_service_client.get_container_client(container_name)
blobs = container_client.list_blobs(name_starts_with=blob_folder_name)
file_pattern = re.compile(rf'^{re.escape(blob_folder_name)}\/.*\.{file_type}$')
count_more_than_size = 0
for blob in blobs:
    blob_name = blob.name
    blob_creation_date = blob.creation_time.date()
    print(blob_name)
    if file_pattern.match(blob_name) and blob_creation_date <= yesterday_date:
        print(f'working on {blob_name}')
        blob_client = container_client.get_blob_client(blob_name)
        blob_data = blob_client.download_blob()
        file_data = blob_data.readall().decode('utf-8')
        filename = blob_name.split("/")[-1].split(".")[0]
        print(filename)
        if blob.size > 16000000:
            count_more_than_size = 1
            put_xml(file_data)
        else:
            copy_into_sf(session, blob_folder_name, filename)
else:
    print("No file found in the specified container and folder.")
# Out:
# xmls
# xmls/0006XO4MWT.xml
# working on xmls/0006XO4MWT.xml
# 0006XO4MWT
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/xmls/0006XO4MWT.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# xmls/0006XOB39Z.xml
# working on xmls/0006XOB39Z.xml
# 0006XOB39Z
# working for child pb001BackgroundReportData
# putting pb001BackgroundReportData at chunked_xmls/pb001BackgroundReportData.xml
# working for child pb001ClaimNonDetailData
# putting pb001ClaimNonDetailData_0 at chunked_xmls/pb001ClaimNonDetailData_0.xml
# putting pb001ClaimNonDetailData_1 at chunked_xmls/pb001ClaimNonDetailData_1.xml
# working for child pb001Comments
# putting pb001Comments at chunked_xmls/pb001Comments.xml
# working for child pb001CommentsClaimLevel
# putting pb001CommentsClaimLevel at chunked_xmls/pb001CommentsClaimLevel.xml
# working for child pb001CustomerServiceData
# putting pb001CustomerServiceData at chunked_xmls/pb001CustomerServiceData.xml
# working for child pb001DocumentSummaryData
# putting pb001DocumentSummaryData at chunked_xmls/pb001DocumentSummaryData.xml
# working for child pb001EnhancedNotificationMessages
# putting pb001EnhancedNotificationMessages at chunked_xmls/pb001EnhancedNotificationMessages.xml
# working for child pb001EPaymentSupplemental
# putting pb001EPaymentSupplemental at chunked_xmls/pb001EPaymentSupplemental.xml
# working for child pb001ErisaTextData
# putting pb001ErisaTextData at chunked_xmls/pb001ErisaTextData.xml
# working for child pb001GroupInfoData
# putting pb001GroupInfoData at chunked_xmls/pb001GroupInfoData.xml
# working for child pb001IRS1095CoveredIndividualA
# putting pb001IRS1095CoveredIndividualA at chunked_xmls/pb001IRS1095CoveredIndividualA.xml
# working for child pb001IRS1095CoveredIndividualB
# putting pb001IRS1095CoveredIndividualB at chunked_xmls/pb001IRS1095CoveredIndividualB.xml
# working for child pb001PaymentDistributionData
# putting pb001PaymentDistributionData at chunked_xmls/pb001PaymentDistributionData.xml
# working for child pb001RemarkCodeDescription
# putting pb001RemarkCodeDescription at chunked_xmls/pb001RemarkCodeDescription.xml
# working for child pb001ServiceLineData
# putting pb001ServiceLineData_0 at chunked_xmls/pb001ServiceLineData_0.xml
# putting pb001ServiceLineData_1 at chunked_xmls/pb001ServiceLineData_1.xml
# working for child pb001ServiceLineTotals
# putting pb001ServiceLineTotals at chunked_xmls/pb001ServiceLineTotals.xml
# working for child pb001SupplementalData
# putting pb001SupplementalData at chunked_xmls/pb001SupplementalData.xml
# working for child pbAllMainReportInstructions
# putting pbAllMainReportInstructions at chunked_xmls/pbAllMainReportInstructions.xml
# working for child PrintOnceTable
# putting PrintOnceTable at chunked_xmls/PrintOnceTable.xml
# working for child tbReleaseFormatAllPrintBlobMasterDelivery
# putting tbReleaseFormatAllPrintBlobMasterDelivery at chunked_xmls/tbReleaseFormatAllPrintBlobMasterDelivery.xml
# working for child tbReleaseFormatAllPrintBlobOverlays
# putting tbReleaseFormatAllPrintBlobOverlays at chunked_xmls/tbReleaseFormatAllPrintBlobOverlays.xml
# working for child tbReleaseFormatAllPrintBlobReturnAddresses
# putting tbReleaseFormatAllPrintBlobReturnAddresses at chunked_xmls/tbReleaseFormatAllPrintBlobReturnAddresses.xml
# working for child tbReportSetImposition
# putting tbReportSetImposition at chunked_xmls/tbReportSetImposition.xml
# No file found in the specified container and folder.

# %%
# delete folder in azure blob
delete_folder = f'{chunked_folder_name}/'


def delete_blobs_in_folder(container_client, folder):
    blob_list = container_client.list_blobs(name_starts_with=folder)
    
    for blob in blob_list:
        container_client.delete_blob(blob.name)

def del_chunked_xmls():
    blob_service_client = BlobServiceClient.from_connection_string(connection_string)
    container_client = blob_service_client.get_container_client(container_name)

    # Delete blobs within the folder
    delete_blobs_in_folder(container_client, delete_folder)

    # After deleting blobs, attempt to delete the folder
    container_client.delete_blob(chunked_folder_name)

    
    try:
        container_client.delete_blob(delete_folder)
        print(f"Folder '{delete_folder}' deleted successfully.")
    except Exception as e:
        print(f"Error deleting folder '{delete_folder}': {str(e)}")

# %%
if count_more_than_size == 1:
    chunked_blobs = container_client.list_blobs(name_starts_with=chunked_folder_name)
    for blob in chunked_blobs:
        blob_name = blob.name
        print(f'working on {blob_name}')
        blob_client = container_client.get_blob_client(blob_name)
        blob_data = blob_client.download_blob()
        file_data = blob_data.readall().decode('utf-8')
        filename = blob_name.split("/")[-1].split(".")[0]
        print(filename)
        copy_into_sf(session, chunked_folder_name, filename)

del_chunked_xmls()
# Out:
# working on chunked_xmls
# chunked_xmls
# [Row(status='Copy executed with 0 files processed.')]
# working on chunked_xmls/PrintOnceTable.xml
# PrintOnceTable
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/PrintOnceTable.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001BackgroundReportData.xml
# pb001BackgroundReportData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001BackgroundReportData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ClaimNonDetailData_0.xml
# pb001ClaimNonDetailData_0
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ClaimNonDetailData_0.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ClaimNonDetailData_1.xml
# pb001ClaimNonDetailData_1
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ClaimNonDetailData_1.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001Comments.xml
# pb001Comments
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001Comments.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001CommentsClaimLevel.xml
# pb001CommentsClaimLevel
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001CommentsClaimLevel.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001CustomerServiceData.xml
# pb001CustomerServiceData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001CustomerServiceData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001DocumentSummaryData.xml
# pb001DocumentSummaryData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001DocumentSummaryData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001EPaymentSupplemental.xml
# pb001EPaymentSupplemental
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001EPaymentSupplemental.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001EnhancedNotificationMessages.xml
# pb001EnhancedNotificationMessages
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001EnhancedNotificationMessages.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ErisaTextData.xml
# pb001ErisaTextData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ErisaTextData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001GroupInfoData.xml
# pb001GroupInfoData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001GroupInfoData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001IRS1095CoveredIndividualA.xml
# pb001IRS1095CoveredIndividualA
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001IRS1095CoveredIndividualA.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001IRS1095CoveredIndividualB.xml
# pb001IRS1095CoveredIndividualB
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001IRS1095CoveredIndividualB.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001PaymentDistributionData.xml
# pb001PaymentDistributionData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001PaymentDistributionData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001RemarkCodeDescription.xml
# pb001RemarkCodeDescription
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001RemarkCodeDescription.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ServiceLineData_0.xml
# pb001ServiceLineData_0
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ServiceLineData_0.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ServiceLineData_1.xml
# pb001ServiceLineData_1
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ServiceLineData_1.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001ServiceLineTotals.xml
# pb001ServiceLineTotals
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001ServiceLineTotals.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pb001SupplementalData.xml
# pb001SupplementalData
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pb001SupplementalData.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/pbAllMainReportInstructions.xml
# pbAllMainReportInstructions
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/pbAllMainReportInstructions.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/tbReleaseFormatAllPrintBlobMasterDelivery.xml
# tbReleaseFormatAllPrintBlobMasterDelivery
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/tbReleaseFormatAllPrintBlobMasterDelivery.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/tbReleaseFormatAllPrintBlobOverlays.xml
# tbReleaseFormatAllPrintBlobOverlays
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/tbReleaseFormatAllPrintBlobOverlays.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/tbReleaseFormatAllPrintBlobReturnAddresses.xml
# tbReleaseFormatAllPrintBlobReturnAddresses
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/tbReleaseFormatAllPrintBlobReturnAddresses.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# working on chunked_xmls/tbReportSetImposition.xml
# tbReportSetImposition
# [Row(file='azure://myadlsatic.blob.core.windows.net/gold/chunked_xmls/tbReportSetImposition.xml', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]
# Error deleting folder 'chunked_xmls/': The requested URI does not represent any resource on the server.
# RequestId:c59aa66c-601e-0029-7485-65575a000000
# Time:2024-02-22T11:54:15.1851729Z
# ErrorCode:InvalidUri
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>InvalidUri</Code><Message>The requested URI does not represent any resource on the server.
# RequestId:c59aa66c-601e-0029-7485-65575a000000
# Time:2024-02-22T11:54:15.1851729Z</Message></Error>
